# %%
import pandas as pd
import nltk
import string

# Download NLTK resources (only needed once)
nltk.download('stopwords')
nltk.download('punkt')

# %%
df = pd.read_csv('course_info.tsv', sep='\t')
df.head(2)
# Out:
#                                  courseName                 universityName  \
# 0  3D Design for Virtual Environments - MSc  Glasgow Caledonian University
# 1              Accounting and Finance - MSc            University of Leeds
#
#                                    facultyName isItFullTime  \
# 0  School of Engineering and Built Environment    Full time
# 1             Leeds University Business School    Full time
#
#                                          description  startDate  \
# 0  3D visualisation and animation play a role in ...  September
# 1  Businesses and governments rely on sound finan...  September
#
#                                                 fees modality  \
# 0  Please see the university website for further ...      MSc
# 1  UK: £18,000 (Total)International: £34,750 (Total)      MSc
#
#            duration     city         country administration  \
# 0  1 year full-time  Glasgow  United Kingdom      On Campus
# 1  1 year full time    Leeds  United Kingdom      On Campus
#
#                                                  url
# 0  https://www.findamasters.com/masters-degrees/c...
# 1  https://www.findamasters.com/masters-degrees/c...

# %%
df.iloc[-2]['fees']
# Out:
# 'Band 2UK fees:Please see the university website for further information on fees for this course.International fees:Please see the university website for further information on fees for this course.'

# %% [markdown]
# ## 2.0 Preprocessing

# %%
def preprocess_text(description):
    # Convert to lowercase
    description = description.lower()
    
    # Remove punctuation
    for char in string.punctuation:
        description = description.replace(char, '')
    
    # Tokenize
    tokens = nltk.word_tokenize(description)

    # Remove stopwords
    stop_words = set(nltk.corpus.stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    # Stemming
    stemmer = nltk.PorterStemmer()
    tokens = [stemmer.stem(word) for word in tokens]

    # Join tokens back into a string
    processed_text = ' '.join(tokens)

    return processed_text

df['description'] = df.description.apply(preprocess_text)
df.head()
# Out:
#                                           courseName  \
# 0           3D Design for Virtual Environments - MSc
# 1                       Accounting and Finance - MSc
# 2  Accounting, Accountability & Financial Managem...
# 3  Accounting, Financial Management and Digital B...
# 4                                     Addictions MSc
#
#                   universityName  \
# 0  Glasgow Caledonian University
# 1            University of Leeds
# 2          King’s College London
# 3          University of Reading
# 4          King’s College London
#
#                                          facultyName isItFullTime  \
# 0        School of Engineering and Built Environment    Full time
# 1                   Leeds University Business School    Full time
# 2                             King’s Business School    Full time
# 3                             Henley Business School    Full time
# 4  Institute of Psychiatry, Psychology and Neuros...    Full time
#
#                                          description  startDate  \
# 0  3d visualis anim play role mani area popular m...  September
# 1  busi govern reli sound financi knowledg underp...  September
# 2  account account financi manag msc cours provid...  September
# 3  embark profession account career academ ground...  September
# 4  join us onlin session prospect student find ms...  September
#
#                                                 fees modality  \
# 0  Please see the university website for further ...      MSc
# 1  UK: £18,000 (Total)International: £34,750 (Total)      MSc
# 2  Please see the university website for further ...      MSc
# 3  Please see the university website for further ...      MSc
# 4  Please see the university website for further ...      MSc
#
#            duration     city         country administration  \
# 0  1 year full-time  Glasgow  United Kingdom      On Campus
# 1  1 year full time    Leeds  United Kingdom      On Campus
# 2         1 year FT   London  United Kingdom      On Campus
# 3  1 year full time  Reading  United Kingdom      On Campus
# 4       One year FT   London  United Kingdom      On Campus
#
#                                                  url
# 0  https://www.findamasters.com/masters-degrees/c...
# 1  https://www.findamasters.com/masters-degrees/c...
# 2  https://www.findamasters.com/masters-degrees/c...
# 3  https://www.findamasters.com/masters-degrees/c...
# 4  https://www.findamasters.com/masters-degrees/c...

# %% [markdown]
# ### 2.0.1) Preprocessing the fees column

# %%
import re
from forex_python.converter import CurrencyRates

df = pd.read_csv('course_info.tsv', sep='\t')
def preprocess_fees(fees, target_currency='USD'):
    if isinstance(fees, str):
        # Extract numeric values from the fees using regex
        fees = fees.replace(',', '').replace('.', '')
        fees_values = [int(match.group()) for match in re.finditer(r'[0-9]+', fees) if int(match.group()) != 2023 and int(match.group()) > 100]

        if fees_values:
            # Convert to the target currency
            c = CurrencyRates()
            converted_fees = [c.convert('USD', target_currency, value) for value in fees_values]

            # Return the highest fee
            highest_fee = max(converted_fees, default=None)
            return highest_fee
        else:
            # Return None for non-numeric strings
            return None
    else:
        # Return None for non-string input
        return None

# Apply the function to the 'fees' column
df['fees'] = df['fees'].apply(preprocess_fees)
df.head()
# Out:
#                                           courseName  \
# 0           3D Design for Virtual Environments - MSc
# 1                       Accounting and Finance - MSc
# 2  Accounting, Accountability & Financial Managem...
# 3  Accounting, Financial Management and Digital B...
# 4                                     Addictions MSc
#
#                   universityName  \
# 0  Glasgow Caledonian University
# 1            University of Leeds
# 2          King’s College London
# 3          University of Reading
# 4          King’s College London
#
#                                          facultyName isItFullTime  \
# 0        School of Engineering and Built Environment    Full time
# 1                   Leeds University Business School    Full time
# 2                             King’s Business School    Full time
# 3                             Henley Business School    Full time
# 4  Institute of Psychiatry, Psychology and Neuros...    Full time
#
#                                          description  startDate     fees  \
# 0  3D visualisation and animation play a role in ...  September      NaN
# 1  Businesses and governments rely on sound finan...  September  34750.0
# 2  Our Accounting, Accountability & Financial Man...  September      NaN
# 3  Embark on a professional accounting career wit...  September      NaN
# 4  Join us for an online session for prospective ...  September      NaN
#
#   modality          duration     city         country administration  \
# 0      MSc  1 year full-time  Glasgow  United Kingdom      On Campus
# 1      MSc  1 year full time    Leeds  United Kingdom      On Campus
# 2      MSc         1 year FT   London  United Kingdom      On Campus
# 3      MSc  1 year full time  Reading  United Kingdom      On Campus
# 4      MSc       One year FT   London  United Kingdom      On Campus
#
#                                                  url
# 0  https://www.findamasters.com/masters-degrees/c...
# 1  https://www.findamasters.com/masters-degrees/c...
# 2  https://www.findamasters.com/masters-degrees/c...
# 3  https://www.findamasters.com/masters-degrees/c...
# 4  https://www.findamasters.com/masters-degrees/c...

# %%
def get_tokens(description):
    # Convert to lowercase
    description = description.lower()
    description = description.replace('-', ' ')
    
    # Remove punctuation
    for char in string.punctuation:
        description = description.replace(char, '')
    
    # Tokenize
    tokens = nltk.word_tokenize(description)

    # Remove stopwords
    stop_words = set(nltk.corpus.stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    # Stemming
    stemmer = nltk.PorterStemmer()
    tokens = [stemmer.stem(word) for word in tokens]
    
    return tokens

def create_vocabulary(tokens):
    voc = {}
    i = 0
    for token in tokens:
        for t in token:
            if t not in voc:
                voc[t] = i
                i += 1
    return voc 

tk = df['description'].apply(get_tokens)
vocabulary = create_vocabulary(tk)

# %%
import pickle
with open('vocabulary.pkl', 'wb') as f:
    pickle.dump(vocabulary, f)
    
#with open('vocabulary.pkl', 'rb') as f:
#    d = pickle.load(f)
#    
#print(d)

# %%
vocabulary
# Out:
# {'3d': 0,
#  'visualis': 1,
#  'anim': 2,
#  'play': 3,
#  'role': 4,
#  'mani': 5,
#  'area': 6,
#  'popular': 7,
#  'media': 8,
#  'keep': 9,
#  'grow': 10,
#  'digit': 11,
#  'provid': 12,
#  'eye': 13,
#  'catch': 14,
#  'special': 15,
#  'effect': 16,
#  '21st': 17,
#  'centuri': 18,
#  'favourit': 19,
#  'film': 20,
#  'televis': 21,
#  'show': 22,
#  'design': 23,
#  'also': 24,
#  'essenti': 25,
#  'everyday': 26,
#  'work': 27,
#  'everyth': 28,
#  'comput': 29,
#  'game': 30,
#  'develop': 31,
#  'onlin': 32,
#  'virtual': 33,
#  'world': 34,
#  'industri': 35,
#  'market': 36,
#  'product': 37,
#  'architecturegcu': 38,
#  'programm': 39,
#  'environ': 40,
#  'help': 41,
#  'skill': 42,
#  'thrive': 43,
#  'success': 44,
#  'career': 45,
#  'visual': 46,
#  'practic': 47,
#  'focus': 48,
#  'orient': 49,
#  'toward': 50,
#  'current': 51,
#  'need': 52,
#  'technolog': 53,
#  'prior': 54,
#  'knowledg': 55,
#  'requir': 56,
#  'busi': 57,
#  'govern': 58,
#  'reli': 59,
#  'sound': 60,
#  'financi': 61,
#  'underpin': 62,
#  'strategi': 63,
#  'successthi': 64,
#  'cours': 65,
#  'kick': 66,
#  'start': 67,
#  'profession': 68,
#  'advanc': 69,
#  'modern': 70,
#  'theori': 71,
#  'account': 72,
#  'control': 73,
#  'well': 74,
#  'understand': 75,
#  'organis': 76,
#  'contextyoul': 77,
#  'cover': 78,
#  'fundament': 79,
#  'topic': 80,
#  'corpor': 81,
#  'financ': 82,
#  'report': 83,
#  'option': 84,
#  'modul': 85,
#  'allow': 86,
#  'specialis': 87,
#  'rang': 88,
#  'intern': 89,
#  'forens': 90,
#  '’': 91,
#  'abl': 92,
#  'appli': 93,
#  'learn': 94,
#  'case': 95,
#  'studi': 96,
#  'simul': 97,
#  'test': 98,
#  'genuin': 99,
#  'scenario': 100,
#  'manag': 101,
#  'msc': 102,
#  'econom': 103,
#  'technic': 104,
#  'institut': 105,
#  'foundat': 106,
#  'managementyoul': 107,
#  'explor': 108,
#  'import': 109,
#  'inform': 110,
#  'ethic': 111,
#  'global': 112,
#  'undergradu': 113,
#  'degre': 114,
#  'relev': 115,
#  'social': 116,
#  'scienc': 117,
#  'subject': 118,
#  'youll': 119,
#  'readi': 120,
#  'tackl': 121,
#  'intellectu': 122,
#  'challeng': 123,
#  'financethrough': 124,
#  'combin': 125,
#  'core': 126,
#  'choic': 127,
#  'come': 128,
#  'away': 129,
#  'fulli': 130,
#  'equip': 131,
#  'choos': 132,
#  'go': 133,
#  'embark': 134,
#  'academ': 135,
#  'groundingth': 136,
#  'distinct': 137,
#  'flavour': 138,
#  'concept': 139,
#  'analys': 140,
#  'offer': 141,
#  'critic': 142,
#  'issu': 143,
#  'relat': 144,
#  'strateg': 145,
#  'plu': 146,
#  'peopl': 147,
#  'addit': 148,
#  'includ': 149,
#  'join': 150,
#  'us': 151,
#  'session': 152,
#  'prospect': 153,
#  'student': 154,
#  'find': 155,
#  'addict': 156,
#  'take': 157,
#  'placewednesday': 158,
#  '17th': 159,
#  'may': 160,
#  '12': 161,
#  '1245pmbook': 162,
#  'onlineour': 163,
#  'postgradu': 164,
#  'educ': 165,
#  'particular': 166,
#  'emphasi': 167,
#  'recent': 168,
#  'biolog': 169,
#  'psycholog': 170,
#  'socio': 171,
#  'environment': 172,
#  'conceptualis': 173,
#  'drug': 174,
#  'use': 175,
#  'prevent': 176,
#  'theoret': 177,
#  'posit': 178,
#  'within': 179,
#  'context': 180,
#  'polici': 181,
#  'facilit': 182,
#  'transfer': 183,
#  'workplac': 184,
#  'chemic': 185,
#  'engin': 186,
#  'leed': 187,
#  'build': 188,
#  'alreadi': 189,
#  'continu': 190,
#  'evolv': 191,
#  'disciplineth': 192,
#  'specif': 193,
#  'greater': 194,
#  'depth': 195,
#  'aspect': 196,
#  'date': 197,
#  'process': 198,
#  'enabl': 199,
#  'oper': 200,
#  'associ': 201,
#  'manufactur': 202,
#  'plant': 203,
#  'whilst': 204,
#  'leadership': 205,
#  'innov': 206,
#  'research': 207,
#  'progress': 208,
#  'physiotherapist': 209,
#  'nh': 210,
#  'privat': 211,
#  'sector': 212,
#  'health': 213,
#  'care': 214,
#  'set': 215,
#  'exist': 216,
#  'clinic': 217,
#  'assess': 218,
#  'analysi': 219,
#  'insightlearn': 220,
#  'state': 221,
#  'art': 222,
#  'facil': 223,
#  'latest': 224,
#  'get': 225,
#  'lead': 226,
#  'edg': 227,
#  'train': 228,
#  'physiotherapi': 229,
#  'gcu': 230,
#  'collabor': 231,
#  'bring': 232,
#  'cut': 233,
#  'seek': 234,
#  'deliv': 235,
#  'practis': 236,
#  'expert': 237,
#  'specialist': 238,
#  '–': 239,
#  'field': 240,
#  'goal': 241,
#  'pro\xadgrammewould': 242,
#  'like': 243,
#  'involv': 244,
#  'solut': 245,
#  'futur': 246,
#  'food': 247,
#  'energi': 248,
#  'climat': 249,
#  'chang': 250,
#  'popul': 251,
#  'growth': 252,
#  'limit': 253,
#  'resourc': 254,
#  'interest': 255,
#  'welfar': 256,
#  'clean': 257,
#  'soil': 258,
#  'newest': 259,
#  'method': 260,
#  'genet': 261,
#  'would': 262,
#  'autom': 263,
#  'robot': 264,
#  'agriculturejoin': 265,
#  'master': 266,
#  'agricultur': 267,
#  'theviikki': 268,
#  'campusto': 269,
#  'today': 270,
#  'tomorrow': 271,
#  'univers': 272,
#  'helsinki': 273,
#  'finland': 274,
#  'pro\xadgrammear': 275,
#  'look': 276,
#  'forward': 277,
#  'graduat': 278,
#  'employ': 279,
#  'nation': 280,
#  'exampl': 281,
#  'public': 282,
#  'becom': 283,
#  'self': 284,
#  'entrepreneurth': 285,
#  'viikki': 286,
#  'campu': 287,
#  'optim': 288,
#  'uniqu': 289,
#  'upon': 290,
#  'vers': 291,
#  'sustain': 292,
#  'secur': 293,
#  '7': 294,
#  'million': 295,
#  'estim': 296,
#  'die': 297,
#  'everi': 298,
#  'year': 299,
#  'due': 300,
#  'harm': 301,
#  'air': 302,
#  'pollut': 303,
#  'degrad': 304,
#  'qualiti': 305,
#  'caus': 306,
#  'prematur': 307,
#  'mortal': 308,
#  'exceed': 309,
#  'death': 310,
#  'unsaf': 311,
#  'drink': 312,
#  'water': 313,
#  'malaria': 314,
#  'hiv': 315,
#  'factor': 316,
#  'emiss': 317,
#  'fate': 318,
#  'vital': 319,
#  'mitig': 320,
#  'analyt': 321,
#  'toxicolog': 322,
#  'integr': 323,
#  'detail': 324,
#  'comprehens': 325,
#  'applic': 326,
#  'excit': 327,
#  'ai': 328,
#  'big': 329,
#  'data': 330,
#  'cybersecur': 331,
#  'span': 332,
#  'almost': 333,
#  'live': 334,
#  'smartphon': 335,
#  'app': 336,
#  'drive': 337,
#  'assist': 338,
#  'revolutionis': 339,
#  'safeti': 340,
#  'effici': 341,
#  'transport': 342,
#  'systemsdu': 343,
#  'pandem': 344,
#  'remot': 345,
#  'convert': 346,
#  'could': 347,
#  'problem': 348,
#  'solv': 349,
#  'establish': 350,
#  'tool': 351,
#  'techniqu': 352,
#  'creat': 353,
#  'intellig': 354,
#  'algorithm': 355,
#  'softwar': 356,
#  'polit': 357,
#  'uncertainti': 358,
#  'recruit': 359,
#  'demand': 360,
#  'decis': 361,
#  'make': 362,
#  'bank': 363,
#  'beyond': 364,
#  'paper': 365,
#  'real': 366,
#  'give': 367,
#  'insight': 368,
#  'put': 369,
#  'action': 370,
#  'day': 371,
#  'one': 372,
#  'bath': 373,
#  'first': 374,
#  'uk': 375,
#  'emphasis': 376,
#  'time': 377,
#  'press': 378,
#  'opportun': 379,
#  'linguist': 380,
#  'languag': 381,
#  'life': 382,
#  'led': 383,
#  'intercultur': 384,
#  'commun': 385,
#  'discours': 386,
#  'undertak': 387,
#  'project': 388,
#  'part': 389,
#  'car': 390,
#  'resist': 391,
#  'anoth': 392,
#  'frequenc': 393,
#  'electr': 394,
#  'power': 395,
#  'smart': 396,
#  'grid': 397,
#  'kept': 398,
#  'constant': 399,
#  'extern': 400,
#  'disturbancesappli': 401,
#  'mathemat': 402,
#  'concern': 403,
#  'dynam': 404,
#  'system': 405,
#  'appear': 406,
#  'model': 407,
#  'basic': 408,
#  'follow': 409,
#  'numer': 410,
#  'behav': 411,
#  'accord': 412,
#  'desir': 413,
#  'interact': 414,
#  'disciplin': 415,
#  'ecolog': 416,
#  'makersolut': 417,
#  'biodivers': 418,
#  'crisi': 419,
#  'appreci': 420,
#  'influenc': 421,
#  'way': 422,
#  'conserv': 423,
#  'natur': 424,
#  'empow': 425,
#  'healthcar': 426,
#  'leader': 427,
#  'thinker': 428,
#  'multidimension': 429,
#  'challengesdu': 430,
#  'complex': 431,
#  'fast': 432,
#  'determin': 433,
#  '2024': 434,
#  'previous': 435,
#  'adopt': 436,
#  'interdisciplinari': 437,
#  'approach': 438,
#  'tradit': 439,
#  'invit': 440,
#  'consid': 441,
#  'wide': 442,
#  'interrel': 443,
#  'socioeconom': 444,
#  'policymak': 445,
#  'new': 446,
#  'shape': 447,
#  'agenda': 448,
#  'ecosystem': 449,
#  'whether': 450,
#  'servic': 451,
#  '\ufeffthe': 452,
#  'pioneer': 453,
#  'togeth': 454,
#  'signific': 455,
#  'reflect': 456,
#  'across': 457,
#  'extend': 458,
#  'piec': 459,
#  'end': 460,
#  'histori': 461,
#  'connect': 462,
#  'differ': 463,
#  'draw': 464,
#  'comparison': 465,
#  'space': 466,
#  'culturesit': 467,
#  'strengthen': 468,
#  'independ': 469,
#  'prepar': 470,
#  'increasingli': 471,
#  'globalis': 472,
#  'major': 473,
#  'stem': 474,
#  'local': 475,
#  'archiv': 476,
#  'museum': 477,
#  'librari': 478,
#  'histor': 479,
#  'hand': 480,
#  'peacebuild': 481,
#  'mutual': 482,
#  'reinforc': 483,
#  'link': 484,
#  'peac': 485,
#  'societi': 486,
#  'especi': 487,
#  'blend': 488,
#  'face': 489,
#  'support': 490,
#  'wholli': 491,
#  'huge': 492,
#  'outcom': 493,
#  'effort': 494,
#  'impact': 495,
#  'refin': 496,
#  'pr': 497,
#  'advertis': 498,
#  'uca': 499,
#  'mamsc': 500,
#  'enhanc': 501,
#  'select': 502,
#  'choicethi': 503,
#  'taught': 504,
#  'school': 505,
#  'creativ': 506,
#  'gain': 507,
#  'deeper': 508,
#  'person': 509,
#  'springboard': 510,
#  'dream': 511,
#  'eight': 512,
#  'cosmet': 513,
#  'beauti': 514,
#  'fashion': 515,
#  'fine': 516,
#  'lifestyl': 517,
#  'good': 518,
#  'luxuri': 519,
#  'music': 520,
#  'mental': 521,
#  'jointli': 522,
#  'run': 523,
#  'king': 524,
#  'colleg': 525,
#  'london': 526,
#  'hygien': 527,
#  'tropic': 528,
#  'medicin': 529,
#  'wish': 530,
#  'surround': 531,
#  'acquir': 532,
#  'implement': 533,
#  'evalu': 534,
#  'low': 535,
#  'conduct': 536,
#  'constitut': 537,
#  'excel': 538,
#  'agenc': 539,
#  'address': 540,
#  'perspectivedur': 541,
#  'contribut': 542,
#  'biggest': 543,
#  'includeglob': 544,
#  'changepandemicscris': 545,
#  'war': 546,
#  'conflictdetermin': 547,
#  'healthhealth': 548,
#  'inequalitiesy': 549,
#  'respond': 550,
#  'improv': 551,
#  'wellb': 552,
#  'individu': 553,
#  'militari': 554,
#  'threat': 555,
#  'defin': 556,
#  'matter': 557,
#  'best': 558,
#  '20th': 559,
#  'quickli': 560,
#  'replac': 561,
#  'emerg': 562,
#  'examin': 563,
#  'convent': 564,
#  'unconvent': 565,
#  'contemporari': 566,
#  'descriptiona': 567,
#  'urgent': 568,
#  'damag': 569,
#  'inequ': 570,
#  'transform': 571,
#  'cultur': 572,
#  'even': 573,
#  'consider': 574,
#  'resili': 575,
#  'align': 576,
#  'mandat': 577,
#  'mission': 578,
#  'respons': 579,
#  'thisbp': 580,
#  'accreditedonlin': 581,
#  'ulster': 582,
#  'stage': 583,
#  '1': 584,
#  'aspir': 585,
#  'psychologistsdo': 586,
#  'hold': 587,
#  'convers': 588,
#  'youth': 589,
#  'intend': 590,
#  'awar': 591,
#  'ill': 592,
#  'pursu': 593,
#  'mscmre': 594,
#  'doctor': 595,
#  'sectordevelop': 596,
#  'throughout': 597,
#  'rise': 598,
#  'machin': 599,
#  'surgic': 600,
#  'avail': 601,
#  'medic': 602,
#  'imag': 603,
#  'open': 604,
#  'sever': 605,
#  'domain': 606,
#  'key': 607,
#  'program': 608,
#  'advantag': 609,
#  'maximis': 610,
#  'potenti': 611,
#  'period': 612,
#  'mediev': 613,
#  'late': 614,
#  'scotland': 615,
#  'britain': 616,
#  'europ': 617,
#  'america': 618,
#  'increas': 619,
#  'perspectivey': 620,
#  'produc': 621,
#  'dissert': 622,
#  'base': 623,
#  'primari': 624,
#  'sourc': 625,
#  'glasgow': 626,
#  'rate': 627,
#  'joint': 628,
#  '4th': 629,
#  'direct': 630,
#  'teach': 631,
#  'human': 632,
#  'physiolog': 633,
#  'function': 634,
#  'muscular': 635,
#  'respiratori': 636,
#  'cardiovascular': 637,
#  'extrem': 638,
#  'condit': 639,
#  'whole': 640,
#  'bodi': 641,
#  'renown': 642,
#  'pro\xadgrammewhi': 643,
#  'eat': 644,
#  'happen': 645,
#  'nutrit': 646,
#  'maintain': 647,
#  'discuss': 648,
#  'behaviourth': 649,
#  'behaviour': 650,
#  'perspect': 651,
#  'thought': 652,
#  'inspir': 653,
#  'built': 654,
#  'around': 655,
#  'consumptionth': 656,
#  'programmein': 657,
#  'biomed': 658,
#  'order': 659,
#  'rounder': 660,
#  'finish': 661,
#  'ageneralist': 662,
#  'fieldyou': 663,
#  'thorough': 664,
#  'thebas': 665,
#  'along': 666,
#  'overview': 667,
#  'themain': 668,
#  'applicationsus': 669,
#  'variou': 670,
#  'signal': 671,
#  'physic': 672,
#  'devic': 673,
#  'tissu': 674,
#  'biomateri': 675,
#  'alongsid': 676,
#  'thenecessari': 677,
#  'skillsthat': 678,
#  'onperman': 679,
#  'ever': 680,
#  'materi': 681,
#  'aim': 682,
#  'healthcarebiomed': 683,
#  'often': 684,
#  'refer': 685,
#  'benefit': 686,
#  'overviewbiomed': 687,
#  'principl': 688,
#  'deliveri': 689,
#  'developmentthi': 690,
#  'theschool': 691,
#  'engineeringand': 692,
#  'nutritionto': 693,
#  'true': 694,
#  'overviewsolv': 695,
#  'engineeringyoul': 696,
#  'biocompat': 697,
#  'respect': 698,
#  'activ': 699,
#  'bio': 700,
#  'structur': 701,
#  'monitor': 702,
#  'prosthet': 703,
#  'limb': 704,
#  'multidisciplinari': 705,
#  'biomechan': 706,
#  'measur': 707,
#  'four': 708,
#  'theme': 709,
#  'diagnost': 710,
#  'rehabilit': 711,
#  'cell': 712,
#  'biologyovervieww': 713,
#  'home': 714,
#  '35': 715,
#  'phd': 716,
#  'divers': 717,
#  'infecti': 718,
#  'diseas': 719,
#  'brain': 720,
#  'interfac': 721,
#  'differenti': 722,
#  'nanotechnolog': 723,
#  'orthot': 724,
#  'aid': 725,
#  'creation': 726,
#  'artifici': 727,
#  'cellsresearch': 728,
#  'areasour': 729,
#  'expertis': 730,
#  'areasadvanc': 731,
#  'began': 732,
#  '1991': 733,
#  'necessari': 734,
#  'succeed': 735,
#  'fastest': 736,
#  'disciplinesthi': 737,
#  'stream': 738,
#  'accredit': 739,
#  'suitabl': 740,
#  'degreewith': 741,
#  'push': 742,
#  'novel': 743,
#  'therapeut': 744,
#  'healthcareth': 745,
#  'interestbiomechanicalbiomaterialsbioelectricalregulatori': 746,
#  'sciencesyoul': 747,
#  'common': 748,
#  'award': 749,
#  'engineeringbiomechan': 750,
#  'discov': 751,
#  'intercal': 752,
#  'fluid': 753,
#  'mechan': 754,
#  'innovationsintroductionbiomed': 755,
#  'worldwid': 756,
#  'next': 757,
#  'gener': 758,
#  'place': 759,
#  'intersect': 760,
#  'cardiac': 761,
#  'silico': 762,
#  'regener': 763,
#  'vitro': 764,
#  'attribut': 765,
#  'synthes': 766,
#  'healthth': 767,
#  'strongli': 768,
#  'larg': 769,
#  'array': 770,
#  'regulatori': 771,
#  'affair': 772,
#  'cancer': 773,
#  'therapi': 774,
#  'electrophysiolog': 775,
#  'biosensor': 776,
#  'microfluid': 777,
#  'optogenet': 778,
#  'ultrasound': 779,
#  'strathclyd': 780,
#  'multi': 781,
#  'win': 782,
#  'higher': 783,
#  'twiceth': 784,
#  'modular': 785,
#  'broad': 786,
#  'nhswe': 787,
#  'researchth': 788,
#  'chosen': 789,
#  'practition': 790,
#  'healththi': 791,
#  'ideal': 792,
#  'your': 793,
#  'want': 794,
#  'better': 795,
#  'treatment': 796,
#  'overviewth': 797,
#  'scale': 798,
#  'entir': 799,
#  'smaller': 800,
#  'nanoparticl': 801,
#  'two': 802,
#  'facilitiescurr': 803,
#  'think': 804,
#  'insid': 805,
#  'mri': 806,
#  'ct': 807,
#  'heart': 808,
#  'valv': 809,
#  'stress': 810,
#  'avoid': 811,
#  'burn': 812,
#  'realis': 813,
#  'microelectron': 814,
#  'keel': 815,
#  'arena': 816,
#  'background': 817,
#  'alli': 818,
#  'informationthi': 819,
#  'majorli': 820,
#  'sought': 821,
#  'competit': 822,
#  'careercours': 823,
#  'overviewwith': 824,
#  'alway': 825,
#  'high': 826,
#  'trend': 827,
#  'cloud': 828,
#  'solid': 829,
#  'coverag': 830,
#  'toolkitintroductionbiomed': 831,
#  'regul': 832,
#  'featurecours': 833,
#  'descriptionthi': 834,
#  'talent': 835,
#  'varieti': 836,
#  'focu': 837,
#  'embed': 838,
#  'academia': 839,
#  'hospit': 840,
#  'medtech': 841,
#  'entrepreneur': 842,
#  'societyprevail': 843,
#  'patient': 844,
#  'centr': 845,
#  'age': 846,
#  'object': 847,
#  'personalis': 848,
#  'herework': 849,
#  'standard': 850,
#  'patholog': 851,
#  'diagnosi': 852,
#  'quest': 853,
#  'cure': 854,
#  'wait': 855,
#  'discoveredour': 856,
#  'semest': 857,
#  'number': 858,
#  'compulsori': 859,
#  'eg': 860,
#  'english': 861,
#  'laboratori': 862,
#  'biostatist': 863,
#  'arm': 864,
#  'scientif': 865,
#  'perform': 866,
#  'second': 867,
#  'write': 868,
#  'review': 869,
#  'internship': 870,
#  'complet': 871,
#  'short': 872,
#  '24': 873,
#  'ect': 874,
#  'total': 875,
#  'grand': 876,
#  'final': 877,
#  'thesi': 878,
#  'result': 879,
#  'obtain': 880,
#  'fourth': 881,
#  'defend': 882,
#  '10': 883,
#  'minut': 884,
#  'oral': 885,
#  'present': 886,
#  'juri': 887,
#  'coursethi': 888,
#  'introduc': 889,
#  'haematopoiet': 890,
#  'normal': 891,
#  'blood': 892,
#  'treatmentsdur': 893,
#  'kingston': 894,
#  'guidanc': 895,
#  'ibm': 896,
#  'registrationan': 897,
#  'depthth': 898,
#  'per': 899,
#  'week': 900,
#  'fit': 901,
#  'commit': 902,
#  'immunolog': 903,
#  'either': 904,
#  'haematolog': 905,
#  'microbiolog': 906,
#  'practicey': 907,
#  'carri': 908,
#  'sell': 909,
#  'point': 910,
#  'job': 911,
#  'promotiony': 912,
#  'entrepreneurship': 913,
#  'courseour': 914,
#  'staff': 915,
#  'guest': 916,
#  'speaker': 917,
#  'organ': 918,
#  'pathogensan': 919,
#  'promotionth': 920,
#  'scientist': 921,
#  'meaning': 922,
#  'step': 923,
#  'leaddesign': 924,
#  'kind': 925,
#  'citi': 926,
#  'lab': 927,
#  'attain': 928,
#  'careersgcu': 929,
#  'three': 930,
#  'covid': 931,
#  '19': 932,
#  'refocus': 933,
#  'attent': 934,
#  'virus': 935,
#  'risk': 936,
#  'dementia': 937,
#  'stroke': 938,
#  'pulmonari': 939,
#  'disord': 940,
#  'great': 941,
#  'highli': 942,
#  'coursel': 943,
#  'track': 944,
#  'record': 945,
#  'target': 946,
#  'move': 947,
#  '‘': 948,
#  'size': 949,
#  'lancast': 950,
#  'valuabl': 951,
#  'experi': 952,
#  'forg': 953,
#  'relationship': 954,
#  'spherearea': 955,
#  'fall': 956,
#  'portfolio': 957,
#  'discoveri': 958,
#  'level': 959,
#  'programmethi': 960,
#  'disciplinethi': 961,
#  'team': 962,
#  'theinstitut': 963,
#  'scienceibm': 964,
#  'biochemistri': 965,
#  'immunohaematolog': 966,
#  'cellular': 967,
#  'molecular': 968,
#  'genom': 969,
#  'name': 970,
#  'titl': 971,
#  'qualif': 972,
#  'suit': 973,
#  'amount': 974,
#  'content': 975,
#  'dental': 976,
#  'veterinari': 977,
#  'biotechnolog': 978,
#  'depend': 979,
#  'levelstructurecontentcor': 980,
#  'sciencefrom': 981,
#  'transfus': 982,
#  'famili': 983,
#  'workpleas': 984,
#  'notethi': 985,
#  'visa': 986,
#  'ukcours': 987,
#  'summaryour': 988,
#  'driven': 989,
#  'main': 990,
#  'grant': 991,
#  'propos': 992,
#  'plan': 993,
#  'underli': 994,
#  'save': 995,
#  'ration': 996,
#  'fight': 997,
#  'seriou': 998,
#  'particularli': 999,
#  ...}

# %%
tk
# Out:
# 0       [3d, visualis, anim, play, role, mani, area, p...
# 1       [busi, govern, reli, sound, financi, knowledg,...
# 2       [account, account, financi, manag, msc, cours,...
# 3       [embark, profession, account, career, academ, ...
# 4       [join, us, onlin, session, prospect, student, ...
#                               ...
# 5970    [master, biolog, two, year, msc, programm, spe...
# 5971    [regist, interest, graduat, studi, uclthi, pro...
# 5972    [biomed, molecular, scienc, research, msc, mre...
# 5973    [biomed, analyt, scienc, msc, cours, enabl, de...
# 5974    [msc, programm, design, produc, highli, qualif...
# Name: description, Length: 5975, dtype: object

# %%
def create_inverted_indx(vocabulary, tokens):
    inverted_index = {term_id: set() for term_id in vocabulary.values()}
    
    for i, l in enumerate(tokens):
        for token in l:
            term_id = vocabulary.get(token)
            if term_id is not None:
                inverted_index[term_id].add(i)
                
    return inverted_index
    
inverted_indx = create_inverted_indx(vocabulary, tk)

# %%
inverted_indx[10]
# Out:
# {0,
#  36,
#  39,
#  40,
#  47,
#  49,
#  50,
#  51,
#  53,
#  110,
#  111,
#  117,
#  125,
#  136,
#  142,
#  173,
#  175,
#  176,
#  181,
#  193,
#  208,
#  222,
#  225,
#  230,
#  233,
#  236,
#  240,
#  272,
#  291,
#  295,
#  445,
#  528,
#  689,
#  740,
#  761,
#  789,
#  832,
#  838,
#  847,
#  851,
#  877,
#  881,
#  884,
#  935,
#  960,
#  965,
#  966,
#  974,
#  985,
#  989,
#  993,
#  1019,
#  1020,
#  1109,
#  1117,
#  1134,
#  1138,
#  1142,
#  1143,
#  1144,
#  1145,
#  1146,
#  1147,
#  1148,
#  1155,
#  1163,
#  1165,
#  1166,
#  1167,
#  1169,
#  1172,
#  1192,
#  1193,
#  1194,
#  1200,
#  1203,
#  1207,
#  1209,
#  1217,
#  1218,
#  1246,
#  1250,
#  1257,
#  1272,
#  1286,
#  1309,
#  1314,
#  1315,
#  1318,
#  1319,
#  1325,
#  1328,
#  1332,
#  1336,
#  1338,
#  1339,
#  1355,
#  1392,
#  1399,
#  1489,
#  1490,
#  1494,
#  1498,
#  1505,
#  1507,
#  1513,
#  1527,
#  1533,
#  1537,
#  1539,
#  1549,
#  1559,
#  1563,
#  1571,
#  1573,
#  1575,
#  1577,
#  1584,
#  1652,
#  1654,
#  1755,
#  1843,
#  1844,
#  1890,
#  1936,
#  1953,
#  1998,
#  2006,
#  2041,
#  2071,
#  2082,
#  2085,
#  2092,
#  2096,
#  2106,
#  2139,
#  2142,
#  2179,
#  2188,
#  2205,
#  2206,
#  2245,
#  2248,
#  2249,
#  2252,
#  2254,
#  2271,
#  2279,
#  2326,
#  2339,
#  2405,
#  2488,
#  2501,
#  2515,
#  2522,
#  2528,
#  2549,
#  2561,
#  2572,
#  2578,
#  2593,
#  2598,
#  2672,
#  2674,
#  2706,
#  2713,
#  2763,
#  2767,
#  2777,
#  2783,
#  2786,
#  2805,
#  2818,
#  2820,
#  2825,
#  2885,
#  2895,
#  2896,
#  2909,
#  2932,
#  2956,
#  3009,
#  3018,
#  3019,
#  3044,
#  3057,
#  3087,
#  3092,
#  3095,
#  3117,
#  3124,
#  3203,
#  3216,
#  3223,
#  3245,
#  3250,
#  3251,
#  3271,
#  3279,
#  3280,
#  3281,
#  3286,
#  3294,
#  3298,
#  3313,
#  3337,
#  3350,
#  3355,
#  3402,
#  3419,
#  3421,
#  3433,
#  3434,
#  3452,
#  3468,
#  3507,
#  3511,
#  3534,
#  3549,
#  3555,
#  3588,
#  3595,
#  3643,
#  3648,
#  3650,
#  3669,
#  3691,
#  3692,
#  3695,
#  3697,
#  3726,
#  3756,
#  3794,
#  3818,
#  3833,
#  3848,
#  3850,
#  3851,
#  3852,
#  3854,
#  3858,
#  3868,
#  3874,
#  3896,
#  3900,
#  3912,
#  3937,
#  4018,
#  4023,
#  4042,
#  4056,
#  4076,
#  4112,
#  4127,
#  4145,
#  4172,
#  4181,
#  4220,
#  4254,
#  4273,
#  4275,
#  4282,
#  4288,
#  4306,
#  4458,
#  4479,
#  4518,
#  4530,
#  4553,
#  4563,
#  4568,
#  4587,
#  4591,
#  4608,
#  4615,
#  4638,
#  4660,
#  4693,
#  4711,
#  4733,
#  4734,
#  4754,
#  4766,
#  4767,
#  4768,
#  4812,
#  4821,
#  4835,
#  4836,
#  4855,
#  4874,
#  4895,
#  4914,
#  4916,
#  4962,
#  5001,
#  5015,
#  5071,
#  5073,
#  5076,
#  5137,
#  5138,
#  5139,
#  5148,
#  5154,
#  5161,
#  5188,
#  5221,
#  5230,
#  5284,
#  5285,
#  5289,
#  5310,
#  5331,
#  5339,
#  5344,
#  5370,
#  5389,
#  5399,
#  5411,
#  5413,
#  5414,
#  5485,
#  5489,
#  5494,
#  5510,
#  5516,
#  5536,
#  5542,
#  5545,
#  5546,
#  5547,
#  5549,
#  5554,
#  5622,
#  5696,
#  5729,
#  5736,
#  5759,
#  5761,
#  5763,
#  5764,
#  5781,
#  5785,
#  5794,
#  5822,
#  5824,
#  5862,
#  5891,
#  5906,
#  5919,
#  5927,
#  5933,
#  5937,
#  5947,
#  5950}
